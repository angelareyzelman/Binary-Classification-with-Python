# %%
#%% make arrays
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn import metrics
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score


x0y=list(np.random.uniform(-1,1,200))
x0x=list(np.random.uniform(-1,1,200))

x1x =list(np.random.uniform(-1,1,200))
x1y=list(np.random.uniform(-1,1,200))

fig = plt.subplot()
plt.scatter(x1x,x1y, color = 'b')
plt.scatter(x0x,x0y,color='orange')
plt.xlabel('X')
plt.ylabel('Y')


fold1x = x0x[:40]+x1x[:40]
fold1y = x0y[:40]+x1y[:40]
fold2x = x0x[40:80]+x1x[40:80]
fold2y = x0y[40:80]+x1y[40:80]
fold3x = x0x[80:120]+x1x[80:120]
fold3y = x0y[80:120]+x1y[80:120]
fold4x = x0x[120:160]+x1x[120:160]
fold4y = x0y[120:160]+x1y[120:160]
fold5x = x0x[160:200]+x1x[160:200]
fold5y = x0y[160:200]+x1y[160:200]

trainx=fold1x+fold2x+fold3x+fold5x
trainy = fold1y+fold2y+fold3y+fold5y

Xtrain = np.stack((trainx,trainy)).T
Ytrain=([0]*40+[1]*40)*4

Xtest=np.stack((fold4x,fold4y)).T 
Ytest =[0]*40 +[1]*40

classifier=sklearn.neighbors.KNeighborsClassifier(n_neighbors=1).fit(Xtrain, Ytrain)
Ypred = classifier.predict(Xtest)

cm = confusion_matrix(Ytest,Ypred)
#ac = accuracy_score(Ytest, Ypred)

print(cm)

trainx=fold1x+fold2x+fold3x+fold4x
trainy = fold1y+fold2y+fold3y+fold4y

Xtrain = np.stack((trainx,trainy)).T
Ytrain=([0]*40+[1]*40)*4

Xtest=np.stack((fold5x,fold5y)).T 
Ytest =[0]*40 +[1]*40

classifier=sklearn.neighbors.KNeighborsClassifier(n_neighbors=1).fit(Xtrain, Ytrain)
Ypred = classifier.predict(Xtest)

cm = confusion_matrix(Ytest,Ypred)
#ac = accuracy_score(Ytest, Ypred)

print(cm)

trainx=fold1x+fold2x+fold4x+fold5x
trainy = fold1y+fold2y+fold4y+fold5y

Xtrain = np.stack((trainx,trainy)).T
Ytrain=([0]*40+[1]*40)*4

Xtest=np.stack((fold3x,fold3y)).T 
Ytest =[0]*40 +[1]*40

classifier=sklearn.neighbors.KNeighborsClassifier(n_neighbors=1).fit(Xtrain, Ytrain)
Ypred = classifier.predict(Xtest)

cm = confusion_matrix(Ytest,Ypred)
#ac = accuracy_score(Ytest, Ypred)

print(cm)

trainx=fold1x+fold4x+fold3x+fold5x
trainy = fold1y+fold4y+fold3y+fold5y

Xtrain = np.stack((trainx,trainy)).T
Ytrain=([0]*40+[1]*40)*4

Xtest=np.stack((fold2x,fold2y)).T 
Ytest =[0]*40 +[1]*40

classifier=sklearn.neighbors.KNeighborsClassifier(n_neighbors=1).fit(Xtrain, Ytrain)
Ypred = classifier.predict(Xtest)

cm = confusion_matrix(Ytest,Ypred)
#ac = accuracy_score(Ytest, Ypred)

print(cm)

trainx=fold4x+fold2x+fold3x+fold5x
trainy = fold4y+fold2y+fold3y+fold5y

Xtrain = np.stack((trainx,trainy)).T
Ytrain=([0]*40+[1]*40)*4

Xtest=np.stack((fold1x,fold1y)).T 
Ytest =[0]*40 +[1]*40

classifier=sklearn.neighbors.KNeighborsClassifier(n_neighbors=1).fit(Xtrain, Ytrain)
Ypred = classifier.predict(Xtest)

cm = confusion_matrix(Ytest,Ypred)
#ac = accuracy_score(Ytest, Ypred)

print(cm)

from sklearn.neighbors import KNeighborsClassifier
import numpy as np
import matplotlib.pyplot as plt
import csv
from sklearn.metrics import confusion_matrix, accuracy_score, roc_curve, roc_auc_score


## PART 5 
print("STATS FOR PART 5")

with open("autoData.csv") as auto_file: 
    auto_data = csv.reader(auto_file)
    data = []
    old = []
    new = []
    color = []
    disp_a = []
    horse_a = []
    a_a=[]
    weight_a=[]
    disp = 0
    horse = 0 
    a = 0
    weight = 0
    for line in auto_data:
        disp_a += [int(line[3])]
        horse_a += [int(line[4])]
        disp = int(line[3])
        horse = int(line[4])
        a_a += [(line[5])]
        weight_a += [int(line[6])]
        a = (line[5])
        weight = int(line[6])
        if int(line[1]) <= 74: 
            old  += [[disp, horse, a, weight]]
            color += ["blue"]
        else:
            new += [[disp, horse, a, weight]]
            color += ["red"]


fig = plt.subplots()

plt.scatter(disp_a[-1],horse_a[-1],color = 'red', label = "old")
plt.scatter(disp_a, horse_a, color = color, label = "new")
plt.xlabel("Displacement")
plt.ylabel("Horsepower")
plt.title("Displacement vs. Horsepower")
plt.legend()

plt.show()
plt.xticks(range(0,600, 50))
plt.yticks(range(0,400, 50))


num_per_fold_old = int(len(old)/5)
num_per_fold_new = int(len(new)/5)

fold1_x3 = old[:num_per_fold_old] + new[:num_per_fold_new]

fold2_x3 = old[num_per_fold_old : num_per_fold_old*2] + new[num_per_fold_new : num_per_fold_new*2]

fold3_x3 = old[num_per_fold_old*2 : num_per_fold_old*3] + new[num_per_fold_new*2 : num_per_fold_new*3]

fold4_x3 = old[num_per_fold_old*3 : num_per_fold_old*4] + new[num_per_fold_new*3 : num_per_fold_new*4]

fold5_x3 = old[num_per_fold_old*4 : num_per_fold_old*5] + new[num_per_fold_new*4 : num_per_fold_new*5]


X_train = fold1_x3 + fold2_x3 + fold3_x3 + fold4_x3
Y_train = ([0]*num_per_fold_old+[1]*num_per_fold_new)*4


X_test = fold5_x3
Y_test = [0]*num_per_fold_old + [1]*num_per_fold_new

classifier = KNeighborsClassifier(n_neighbors = 1).fit(X_train, Y_train)
Y_pred = classifier.predict(X_test)

# print stats 
cm = confusion_matrix(Y_test, Y_pred)
ac = accuracy_score(Y_test, Y_pred)
print(cm)

# run 1-NN w/ test fold 4 

X_train = fold1_x3 + fold2_x3 + fold3_x3 + fold5_x3

Y_train = ([0]*num_per_fold_old+[1]*num_per_fold_new)*4

X_test = fold4_x3
Y_test = [0]*num_per_fold_old + [1]*num_per_fold_new

classifier = KNeighborsClassifier(n_neighbors = 1).fit(X_train, Y_train)
Y_pred = classifier.predict(X_test)

# print stats 
cm = confusion_matrix(Y_test, Y_pred)
ac = accuracy_score(Y_test, Y_pred)
print(cm)

# run 1-NN w/ test fold 3 

X_train = fold1_x3 + fold2_x3 + fold5_x3 + fold4_x3

Y_train = ([0]*num_per_fold_old+[1]*num_per_fold_new)*4

X_test =  fold3_x3
Y_test = [0]*num_per_fold_old + [1]*num_per_fold_new

classifier = KNeighborsClassifier(n_neighbors = 1).fit(X_train, Y_train)
Y_pred = classifier.predict(X_test)

# print stats 
cm = confusion_matrix(Y_test, Y_pred)
ac = accuracy_score(Y_test, Y_pred)
print(cm)

# run 1-NN w/ test fold 2 

X_train = fold1_x3 + fold5_x3 + fold3_x3 + fold4_x3
Y_train = ([0]*num_per_fold_old+[1]*num_per_fold_new)*4

X_test =  fold2_x3

classifier = KNeighborsClassifier(n_neighbors = 1).fit(X_train, Y_train)
Y_pred = classifier.predict(X_test)

# print stats 
cm = confusion_matrix(Y_test, Y_pred)
ac = accuracy_score(Y_test, Y_pred)
print(cm)

# run 1-NN w/ test fold 1

X_train = fold5_x3 + fold2_x3 + fold3_x3 + fold4_x3
X_test = fold1_x3
classifier = KNeighborsClassifier(n_neighbors = 1).fit(X_train, Y_train)
Y_pred = classifier.predict(X_test)
# print stats 
cm = confusion_matrix(Y_test, Y_pred)
ac = accuracy_score(Y_test, Y_pred)
print(cm)


# 7 neighbors 
print("7 NEIGHBORS")
X_train = fold1_x3 + fold2_x3 + fold3_x3 + fold4_x3
X_test = fold5_x3
classifier = KNeighborsClassifier(n_neighbors = 7).fit(X_train, Y_train)
Y_pred = classifier.predict(X_test)
# print stats 
cm = confusion_matrix(Y_test, Y_pred)
ac = accuracy_score(Y_test, Y_pred)
print(cm)

# run 1-NN w/ test fold 4 
X_train = fold1_x3 + fold2_x3 + fold3_x3 + fold5_x3
X_test = fold4_x3
classifier = KNeighborsClassifier(n_neighbors = 7).fit(X_train, Y_train)
Y_pred = classifier.predict(X_test)
# print stats 
cm = confusion_matrix(Y_test, Y_pred)
ac = accuracy_score(Y_test, Y_pred)
print(cm)

# run 1-NN w/ test fold 3 
X_train = fold1_x3 + fold2_x3 + fold5_x3 + fold4_x3
X_test =  fold3_x3
classifier = KNeighborsClassifier(n_neighbors = 7).fit(X_train, Y_train)
Y_pred = classifier.predict(X_test)
# print stats 
cm = confusion_matrix(Y_test, Y_pred)
ac = accuracy_score(Y_test, Y_pred)
print(cm)

# run 1-NN w/ test fold 2 
X_train = fold1_x3 + fold5_x3 + fold3_x3 + fold4_x3
X_test =  fold2_x3
classifier = KNeighborsClassifier(n_neighbors = 7).fit(X_train, Y_train)
Y_pred = classifier.predict(X_test)
# print stats 
cm = confusion_matrix(Y_test, Y_pred)
ac = accuracy_score(Y_test, Y_pred)
print(cm)

# run 1-NN w/ test fold 1

X_train = fold5_x3 + fold2_x3 + fold3_x3 + fold4_x3
X_test = fold1_x3
classifier = KNeighborsClassifier(n_neighbors = 7).fit(X_train, Y_train)
Y_pred = classifier.predict(X_test)
# print stats 
cm = confusion_matrix(Y_test, Y_pred)
ac = accuracy_score(Y_test, Y_pred)
print(cm)

y_scores = classifier.predict_proba(X_test)
Y_scores = [i[0] for i in y_scores]


#ROC CURVES 
fpr, tpr, threshold = roc_curve(Y_test, Y_scores)

plt.subplot()
plt.plot(fpr, tpr)
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC Curve")
plt.show()
plt.savefig("q5_d")

auc = roc_auc_score(Y_test, Y_scores)
print("AUC: " + str(auc))
# Out:
# [[18 22]
#  [22 18]]
# [[21 19]
#  [21 19]]
# [[22 18]
#  [16 24]]
# [[23 17]
#  [18 22]]
# [[19 21]
#  [17 23]]
# STATS FOR PART 5
# [[ 6 24]
#  [ 8 40]]
# [[20 10]
#  [17 31]]
# [[14 16]
#  [ 9 39]]
# [[20 10]
#  [13 35]]
# [[14 16]
#  [19 29]]
# 7 NEIGHBORS
# [[10 20]
#  [ 7 41]]
# [[16 14]
#  [10 38]]
# [[18 12]
#  [ 8 40]]
# [[ 9 21]
#  [11 37]]
# [[12 18]
#  [13 35]]
# /Users/angelareyzelman/Library/Python/3.8/lib/python/site-packages/sklearn/utils/validation.py:964: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(
# ...
